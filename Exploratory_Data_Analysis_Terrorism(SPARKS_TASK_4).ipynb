# %% [markdown]
# # AUTHOR:- R.SAI APURVA
# # TASK-4:-
# ## Objective:Exploratory Data Analysis - Terrorism
# ## As a security/defense analyst, try to find out the hot zone of terrorism.
# ## What all security issues and insights you can derive by EDA?

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/globalterrorismdb_0718dist.csv',encoding='ISO-8859-1')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning:
#
# Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
df
# Out:
#              eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0       197000000001   1970       7     2  ...        0         0       0      NaN
# 1       197000000002   1970       0     0  ...        1         1       1      NaN
# 2       197001000001   1970       1     0  ...       -9         1       1      NaN
# 3       197001000002   1970       1     0  ...       -9         1       1      NaN
# 4       197001000003   1970       1     0  ...       -9         1       1      NaN
# ...              ...    ...     ...   ...  ...      ...       ...     ...      ...
# 181686  201712310022   2017      12    31  ...        0         0       0      NaN
# 181687  201712310029   2017      12    31  ...       -9         1       1      NaN
# 181688  201712310030   2017      12    31  ...        0         0       0      NaN
# 181689  201712310031   2017      12    31  ...       -9         0      -9      NaN
# 181690  201712310032   2017      12    31  ...       -9         0      -9      NaN
#
# [181691 rows x 135 columns]

# %%
df.info() #detialed information about the imported 'df'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
#stratigical display of the data
df.describe()
# Out:
#             eventid          iyear  ...       INT_MISC        INT_ANY
# count  1.816910e+05  181691.000000  ...  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997  ...       0.090010      -3.945952
# std    1.325957e+09      13.259430  ...       0.568457       4.691325
# min    1.970000e+11    1970.000000  ...      -9.000000      -9.000000
# 25%    1.991021e+11    1991.000000  ...       0.000000      -9.000000
# 50%    2.009022e+11    2009.000000  ...       0.000000       0.000000
# 75%    2.014081e+11    2014.000000  ...       0.000000       0.000000
# max    2.017123e+11    2017.000000  ...       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
#to print no. of rows and columns in the dataset for better understanding
df.shape
# Out:
# (181691, 135)

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df.columns #check the columns in the data
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
corr=df.corr()
corr  # correlation pf the data
# Out:
#             eventid     iyear    imonth  ...  INT_IDEO  INT_MISC   INT_ANY
# eventid    1.000000  0.999996  0.002706  ... -0.133252 -0.077852 -0.175605
# iyear      0.999996  1.000000  0.000139  ... -0.133253 -0.077847 -0.175596
# imonth     0.002706  0.000139  1.000000  ... -0.002034 -0.002554 -0.006336
# iday       0.018336  0.018254  0.005497  ... -0.001621 -0.002027 -0.001199
# extended   0.091761  0.091754 -0.000468  ...  0.075147  0.027335  0.080767
# ...             ...       ...       ...  ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  ...  0.040947  0.085055  0.064759
# INT_LOG   -0.143600 -0.143601 -0.002302  ...  0.996211  0.052537  0.891051
# INT_IDEO  -0.133252 -0.133253 -0.002034  ...  1.000000  0.082014  0.893811
# INT_MISC  -0.077852 -0.077847 -0.002554  ...  0.082014  1.000000  0.252193
# INT_ANY   -0.175605 -0.175596 -0.006336  ...  0.893811  0.252193  1.000000
#
# [77 rows x 77 columns]

# %% [markdown]
# ## DATA VISUALIZATION

# %%
df.hist(figsize=(50,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f051a095208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519869e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519cb40f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519c54470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519fea7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f051a017b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519d0def0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519c88278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519c882e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0519f749b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519f27d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519ee60f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519f19470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519eca7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519e7db70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519e2fef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519ded2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519e1c630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0519dd19b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519d83d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519d430f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519bf4470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519ba57f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519bd8b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519b8bef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519b4a2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519afb630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0519aad9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519adfd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519aa00f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519a50470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519a027f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05199b5b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519967ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05199262b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519958630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f05199099b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05198bed30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f051983c0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05197ef470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05198207f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05197d2b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519783ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05197422b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05196f3630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f05196a59b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05196d9d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05196970f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f051964a470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05195fc7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05195aeb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05195e0ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f051959f2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f051954f630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f05195039b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05194b3d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05194750f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519427470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05194597f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f051940ab70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05193beef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f051937c2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f051932d630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f05193609b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519313d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05192d10f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519284470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05192357f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05191e7b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519219ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05191d72b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519189630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f051913a9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05190efd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05190ad0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05190e0470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05190907f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0519045b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0518ff6ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0518fb52b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0518f67630>]],
#       dtype=object)

# %% [markdown]
# ## Check which region has highest attacks and in which year

# %%
#Graphical representation of terrorist activities by region
pd.crosstab(df.iyear,df.region_txt).plot(kind='area',figsize=(20,10))
plt.show()

# %% [markdown]
# ## to get the count of attacks

# %%
plt.subplots(figsize=(20,10))
sns.countplot('iyear',data=df,palette='tab10',edgecolor=sns.color_palette("hls", 8))
plt.xticks(rotation=90)
plt.title('no of terror activities')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ### Highest number of attacks took place in year 2014

# %%
yr=df.iyear.value_counts().to_dict()
rate=((yr[2017]-yr[1970])/yr[2017])*100
print('number of attacks in year 2017 is',yr[2017],' and number of attacks in year 1970 is',yr[1970])
# Out:
# number of attacks in year 2017 is 10900  and number of attacks in year 1970 is 651

# %% [markdown]
# ### From this we can say that the there has been a significant increase number of attacks fron 1970 to 2017

# %% [markdown]
# ## now, let's see the type of attack that has been used the most

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['attacktype1_txt'],order=df['attacktype1_txt'].value_counts().index,palette='Paired')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ### From this we can say that Bombing/Explosion have been used the most i.e.; more than 80000 times

# %% [markdown]
# ## Now let's look at the type of places that have been targeted the most

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['targtype1_txt'],order=df['targtype1_txt'].value_counts().index,palette='Paired')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ### Therefore, private citizens & property has been targeted the most i.e; more than 40000 time.

# %% [markdown]
# ## Now,let's look at the countries that are the most under attack

# %%
fig,axes=plt.subplots(figsize=(20,10),nrows=1,ncols=1)
sns.barplot(x=df['country_txt'].value_counts()[:20].values,y=df['country_txt'].value_counts()[:20].index,palette='rocket')

# %% [markdown]
# ## Therefore the country that faces most number of terror attacks is Iraq i.e; about 25000

# %% [markdown]
# ## Now,let's look at the regions that are the most under attack

# %%
fig,axes=plt.subplots(figsize=(20,10),nrows=1,ncols=1)
sns.barplot(x=df['region_txt'].value_counts()[:20].values,y=df['region_txt'].value_counts()[:20].index,palette='mako')

# %% [markdown]
# ## Therefor, the region that is most under attack is Middle East and North Africa with more than 50000 attacks

# %% [markdown]
# ## ANALYSIS ON CUSTOMIZED DATA
# #### Terror attacks in a location/country in particular year

# %%
filterYear = df['iyear'] == 1970

# %%
filterData=df[filterYear]

# %%
filterData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 651 entries, 0 to 650
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 691.7+ KB

# %%
reqFilterData = filterData.loc[:,'city':'longitude']
reqFilterData=reqFilterData.dropna() #remove null values

# %%
reqFilterDataList=reqFilterData.values.tolist()

# %%
map=folium.Map(location=[0,30],tiles='CartoDB positron',zoom_start=2)

# %%
#clustered marker
markerCluster= folium.plugins.MarkerCluster().add_to(map)
for point in range (0, len(reqFilterDataList)):
  folium.Marker(location=[reqFilterDataList[point][1],reqFilterDataList[point][2]],popup=reqFilterDataList[point][0]).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Total number of people killed in terror attacks

# %%
killData=df.loc[:,'nkill']
killData=killData.dropna() #remove null values

# %%
print('Number of people killed in terror attacks',int(sum(killData)))
# Out:
# Number of people killed in terror attacks 411868

# %% [markdown]
# # CONCLUSION:
# ## EDA:
# ### Highest number of attacks took place in year 2014
# ### number of attacks in year 2017 is 10900  and number of attacks in year 1970 is 651
# ### Bombing/Explosion have been used the most
# ### private citizens & property has been targeted the most.
# ### the country that faces most number of terror attacks is Iraq i.e; about 25000
# ### the region that is most under attack is Middle East and North Africa with more than 50000 attacks.
# ### Number of people killed in terror attacks 411868

# %% [markdown]
# # THANK YOU.
